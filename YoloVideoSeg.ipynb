# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
from ultralytics import YOLO
import cv2

# %%
model1 = YOLO('seg.pt', "v8") 
model2 = YOLO('pose.pt', "v8")

# %%
# Display result
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model

# Open the video file
cap = cv2.VideoCapture(0)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model1(frame)
        results2 = model2(results[0].plot())

        # Visualize the results on the frame
        annotated_frame = results2[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 persons, 2 laptops, 1695.4ms
# Speed: 11.0ms preprocess, 1695.4ms inference, 30.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 2 persons, 4341.9ms
# Speed: 15.0ms preprocess, 4341.9ms inference, 3.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 4 persons, 1 laptop, 1506.8ms
# Speed: 3.0ms preprocess, 1506.8ms inference, 12.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 3 persons, 4804.2ms
# Speed: 14.0ms preprocess, 4804.2ms inference, 5.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 2 persons, 1567.5ms
# Speed: 4.0ms preprocess, 1567.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 2 persons, 4609.1ms
# Speed: 16.0ms preprocess, 4609.1ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 6 persons, 1 chair, 2 laptops, 1517.6ms
# Speed: 2.2ms preprocess, 1517.6ms inference, 17.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 3 persons, 4599.4ms
# Speed: 17.0ms preprocess, 4599.4ms inference, 7.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 5 persons, 2 chairs, 2 laptops, 1492.2ms
# Speed: 2.5ms preprocess, 1492.2ms inference, 11.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 4 persons, 4505.6ms
# Speed: 14.8ms preprocess, 4505.6ms inference, 7.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 4 persons, 3 chairs, 1 laptop, 1555.1ms
# Speed: 3.0ms preprocess, 1555.1ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 2 persons, 4510.1ms
# Speed: 13.6ms preprocess, 4510.1ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 4 persons, 1 laptop, 1515.7ms
# Speed: 2.0ms preprocess, 1515.7ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 3 persons, 4506.9ms
# Speed: 14.0ms preprocess, 4506.9ms inference, 8.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 3 persons, 1533.6ms
# Speed: 2.0ms preprocess, 1533.6ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 3 persons, 4495.9ms
# Speed: 17.1ms preprocess, 4495.9ms inference, 2.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 3 persons, 1 laptop, 1442.0ms
# Speed: 2.0ms preprocess, 1442.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 3 persons, 4722.3ms
# Speed: 15.5ms preprocess, 4722.3ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 5 persons, 2 laptops, 1569.7ms
# Speed: 2.0ms preprocess, 1569.7ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 4 persons, 4774.5ms
# Speed: 15.8ms preprocess, 4774.5ms inference, 12.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 6 persons, 1 chair, 1 laptop, 1610.9ms
# Speed: 4.5ms preprocess, 1610.9ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 3 persons, 4386.9ms
# Speed: 15.0ms preprocess, 4386.9ms inference, 3.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 480x640 5 persons, 1 laptop, 1575.0ms
# Speed: 2.0ms preprocess, 1575.0ms inference, 12.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 960x1280 3 persons, 4509.3ms
# Speed: 13.0ms preprocess, 4509.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 1280)
